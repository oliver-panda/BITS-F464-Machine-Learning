# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

# %%
df=pd.read_csv('ML-Om1.csv')
#print (df.to_string())
df
#divide this df into data and target, X=df ka data, y=df ka target
#X_train, X_test, y_train, y_test= train_test_split (X, y, test_size=__, random_state=___)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0    ...        25.380          17.33           184.60      2019.0
# 1    ...        24.990          23.41           158.80      1956.0
# 2    ...        23.570          25.53           152.50      1709.0
# 3    ...        14.910          26.50            98.87       567.7
# 4    ...        22.540          16.67           152.20      1575.0
# ..   ...           ...            ...              ...         ...
# 564  ...        25.450          26.40           166.10      2027.0
# 565  ...        23.690          38.25           155.00      1731.0
# 566  ...        18.980          34.12           126.70      1124.0
# 567  ...        25.740          39.42           184.60      1821.0
# 568  ...         9.456          30.37            59.16       268.6
#
#      smoothness_worst  compactness_worst  concavity_worst  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                  0.2654          0.4601                  0.11890
# 1                  0.1860          0.2750                  0.08902
# 2                  0.2430          0.3613                  0.08758
# 3                  0.2575          0.6638                  0.17300
# 4                  0.1625          0.2364                  0.07678
# ..                    ...             ...                      ...
# 564                0.2216          0.2060                  0.07115
# 565                0.1628          0.2572                  0.06637
# 566                0.1418          0.2218                  0.07820
# 567                0.2650          0.4087                  0.12400
# 568                0.0000          0.2871                  0.07039
#
# [569 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
Y_col = 'diagnosis'
X_cols = (df.loc[:, df.columns != Y_col].columns).drop('id')
print(Y_col)
print(X_cols)
# Out:
# diagnosis
# Index(['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean',
#        'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
df1=df.dropna()
df1.shape
# Out:
# (563, 32)

# %%
df_train = df1.sample(frac=0.67, random_state=1)
df_test=df1.drop(df_train.index)
print (df_train.shape, df_test.shape)
# Out:
# (377, 32) (186, 32)

# %%
X_train = df_train[X_cols]
X_test = df_test[X_cols]
y_train = (((df_train[Y_col]).apply(ord))/11-6).astype('int')
y_test = (((df_test[Y_col]).apply(ord))/11-6).astype('int')
#malignant is 1 benign is 0
print (y_train, y_test)
#for i in y_train:
  #if i=='M':
    #i=1
  #else:
    #i=0
#for i in y_test:
  #if i=='M':
    #i=1
  #else:
    #i=0
#print (y_train, y_test)
# Out:
# 47     1
# 244    1
# 277    1
# 366    1
# 505    0
#       ..
# 565    1
# 343    1
# 45     1
# 303    0
# 479    1
# Name: diagnosis, Length: 377, dtype: int64 2      1
# 7      1
# 10     1
# 15     1
# 20     0
#       ..
# 538    0
# 541    0
# 546    0
# 557    0
# 561    0
# Name: diagnosis, Length: 186, dtype: int64

# %%
X_train=np.array(X_train)
y_train=np.array(y_train)
X_test=np.array(X_test)
y_test=np.array(y_test)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (377, 30) (377,)

# %%
class LogisticRegression():

  def __init__(self, lr, p_thresh, n_iters=1000):
    self.lr=lr
    self.p_thresh=p_thresh
    self.n_iters= n_iters
    self.weights= None
    self.bias= None
  
  def batchfit (self, X, y):
    costl=[]
    el=[]
    n_samples, n_features= X.shape
    self.weights= np.zeros (n_features)
    self.bias= 0

    for i in range (self.n_iters):
      linear_pred= np.dot (X, self.weights)+ self.bias
      predictions= sigmoid(linear_pred)
      cost=(-1/n_samples)*np.sum((y*np.log(predictions) + (1-y)*np.log(1-predictions)))
      cost=np.squeeze(np.array(cost))
      dw= (1/n_samples) * np.dot(X.T, (predictions-y))
      db= (1/n_samples) * np.sum(predictions-y)

      self.weights= self.weights- self.lr*dw
      self.bias=self.bias - self.lr*db
      costl.append(cost)
      el.append(i)
    return costl, el

  def minifit (self, X, y):
    n_samples, n_features= X.shape
    self.weights= np.zeros (n_features)
    self.bias= 0
    costl=[]
    el=[]
    bs=20
    nb=n_samples//bs
    for i in range(self.n_iters):
      for j in range(nb):

        start=j*bs
        end=(j+1)*bs

        Xmini=X[start:end,:].reshape(bs,n_features)
        ymini=y[start:end].reshape(bs,)

        linear_pred= np.dot (Xmini, self.weights)+ self.bias
        predictions= sigmoid(linear_pred)

        dw= (1/bs) * np.dot(Xmini.T, (predictions-ymini))
        db= (1/bs) * np.sum(predictions-ymini)
        cost=(-1/n_samples)*np.sum((ymini*np.log(predictions) + (1-ymini)*np.log(1-predictions)))
        cost=np.squeeze(np.array(cost))
        self.weights= self.weights- self.lr*dw
        self.bias=self.bias - self.lr*db
      costl.append(cost)
      el.append(i)
    return costl, el
  
  
  def sgdfit (self, X, y):
    n_samples, n_features= X.shape
    self.weights= np.zeros (n_features)
    self.bias= 0
    costl=[]
    el=[]

    for i in range(self.n_iters):
      for j in range(n_samples):

        ramji=np.random.randint(0,n_samples)

        Xsgd=X[ramji,:].reshape(1,n_features)
        ysgd=y[ramji].reshape(1,)

        linear_pred= np.dot (Xsgd, self.weights)+ self.bias
        predictions= sigmoid(linear_pred)
        cost=(-1/n_samples)*np.sum((ysgd*np.log(predictions) + (1-ysgd)*np.log(1-predictions)))
        cost=np.squeeze(np.array(cost))
        dw= np.dot(Xsgd.T, (predictions-ysgd))
        db= np.sum(predictions-ysgd)

        self.weights= self.weights- self.lr*dw
        self.bias=self.bias - self.lr*db
      costl.append(cost)
      el.append(i)
    return costl, el




  def predict(self, X):

    linear_pred= np.dot(X, self.weights) +self.bias
    y_pred=sigmoid(linear_pred)

    #y_pred stores probs of testing data points

    class_pred= [0 if y< self.p_thresh else 1 for y in y_pred] #probability thresholds given: 0.5, 0.3, 0.4, 0.6, 0.7
    return class_pred

# %%
l=[0.01,0.001,0.0001]
t=[0.3,0.4,0.5,0.6,0.7]
def accuracy (y_pred, y_test):
  return np.sum (y_pred==y_test)/len(y_test)

print("==================================")
print("Batch")
print("==================================")
for k in l:
  for j in t:
    LR1= LogisticRegression(lr=k,p_thresh=j) #give diff learning rates and prob thresholds
    c, e = LR1.batchfit(X_train, y_train) 
    y_pred=LR1.predict(X_test)
    acc= accuracy(y_pred, y_test)
    print ("For Learning Rate:",k,"and Threshold:",j,"Accuracy:",acc*100,"%")
    print(" ")
    TP=0
    FP=0
    TN=0
    FN=0

    for i in range(len(y_pred)):
      if y_pred[i]==1 and y_test[i]==1:
        TP+=1
      elif y_pred[i]==1 and y_test[i]==0:
        FP+=1
      elif y_pred[i]==0 and y_test[i]==1:
        FN+=1
      elif y_pred[i]==0 and y_test[i]==0:
        TN+=1
    print("Confusion Matrix:")
    print(np.array([[TP,FP],[FN,TN]]))
    print(" ")
    print("Accuracy:", (TP + TN)/(TP + TN + FP + FN))
    print("Precision:", TP/(TP + FP))
    print("Recall:", TP/(TP + FN))
    print(" ")
    costs=np.squeeze(c)
    plt.plot(c)
    plt.xlabel("Cost")
    plt.ylabel("Number of Iterations")
    plt.show()
    print(" ")
    print(" ")

print("==================================")
print("Mini Batch")
print("==================================")
for k in l:
  for j in t:
    LR1= LogisticRegression(lr=k,p_thresh=j) #give diff learning rates and prob thresholds
    c, e = LR1.minifit(X_train, y_train) 
    y_pred=LR1.predict(X_test)
    acc= accuracy(y_pred, y_test)
    print ("For Learning Rate:",k,"and Threshold:",j,"Accuracy:",acc*100,"%")
    print(" ")
    TP=0
    FP=0
    TN=0
    FN=0

    for i in range(len(y_pred)):
      if y_pred[i]==1 and y_test[i]==1:
        TP+=1
      elif y_pred[i]==1 and y_test[i]==0:
        FP+=1
      elif y_pred[i]==0 and y_test[i]==1:
        FN+=1
      elif y_pred[i]==0 and y_test[i]==0:
        TN+=1
    print("Confusion Matrix:")
    print(np.array([[TP,FP],[FN,TN]]))
    print(" ")
    print("Accuracy:", (TP + TN)/(TP + TN + FP + FN))
    print("Precision:", TP/(TP + FP))
    print("Recall:", TP/(TP + FN))
    print(" ")
    costs=np.squeeze(c)
    plt.plot(c)
    plt.xlabel("Cost")
    plt.ylabel("Number of Iterations")
    plt.show()
    print(" ")
    print(" ")

print("==================================")
print("Stochastic")
print("==================================")
for k in l:
  for j in t:
    LR1= LogisticRegression(lr=k,p_thresh=j) #give diff learning rates and prob thresholds
    c, e = LR1.sgdfit(X_train, y_train) 
    y_pred=LR1.predict(X_test)
    acc= accuracy(y_pred, y_test)
    print ("For Learning Rate:",k,"and Threshold:",j,"Accuracy:",acc*100,"%")
    print(" ")
    TP=0
    FP=0
    TN=0
    FN=0

    for i in range(len(y_pred)):
      if y_pred[i]==1 and y_test[i]==1:
        TP+=1
      elif y_pred[i]==1 and y_test[i]==0:
        FP+=1
      elif y_pred[i]==0 and y_test[i]==1:
        FN+=1
      elif y_pred[i]==0 and y_test[i]==0:
        TN+=1
    print("Confusion Matrix:")
    print(np.array([[TP,FP],[FN,TN]]))
    print(" ")
    print("Accuracy:", (TP + TN)/(TP + TN + FP + FN))
    print("Precision:", TP/(TP + FP))
    print("Recall:", TP/(TP + FN))
    print(" ")
    costs=np.squeeze(c)
    plt.plot(c)
    plt.xlabel("Cost")
    plt.ylabel("Number of Iterations")
    plt.show()
    print(" ")
    print(" ")
# Out:
# ==================================
# Batch
# ==================================
# For Learning Rate: 0.01 and Threshold: 0.3 Accuracy: 89.24731182795699 %
#
# Confusion Matrix:
# [[67 15]
#  [ 5 99]]
#
# Accuracy: 0.8924731182795699
# Precision: 0.8170731707317073
# Recall: 0.9305555555555556
#
#
# For Learning Rate: 0.01 and Threshold: 0.4 Accuracy: 89.24731182795699 %
#
# Confusion Matrix:
# [[67 15]
#  [ 5 99]]
#
# Accuracy: 0.8924731182795699
# Precision: 0.8170731707317073
# Recall: 0.9305555555555556
#
#
# For Learning Rate: 0.01 and Threshold: 0.5 Accuracy: 89.24731182795699 %
#
# Confusion Matrix:
# [[67 15]
#  [ 5 99]]
#
# Accuracy: 0.8924731182795699
# Precision: 0.8170731707317073
# Recall: 0.9305555555555556
#
#
# For Learning Rate: 0.01 and Threshold: 0.6 Accuracy: 89.24731182795699 %
#
# Confusion Matrix:
# [[67 15]
#  [ 5 99]]
#
# Accuracy: 0.8924731182795699
# Precision: 0.8170731707317073
# Recall: 0.9305555555555556
#
#
# For Learning Rate: 0.01 and Threshold: 0.7 Accuracy: 89.24731182795699 %
#
# Confusion Matrix:
# [[67 15]
#  [ 5 99]]
#
# Accuracy: 0.8924731182795699
# Precision: 0.8170731707317073
# Recall: 0.9305555555555556
#
#
# For Learning Rate: 0.001 and Threshold: 0.3 Accuracy: 89.24731182795699 %
#
# Confusion Matrix:
# [[67 15]
#  [ 5 99]]
#
# Accuracy: 0.8924731182795699
# Precision: 0.8170731707317073
# Recall: 0.9305555555555556
#
#
# For Learning Rate: 0.001 and Threshold: 0.4 Accuracy: 89.24731182795699 %
#
# Confusion Matrix:
# [[67 15]
#  [ 5 99]]
#
# Accuracy: 0.8924731182795699
# Precision: 0.8170731707317073
# Recall: 0.9305555555555556
#
#
# For Learning Rate: 0.001 and Threshold: 0.5 Accuracy: 89.24731182795699 %
#
# Confusion Matrix:
# [[67 15]
#  [ 5 99]]
#
# Accuracy: 0.8924731182795699
# Precision: 0.8170731707317073
# Recall: 0.9305555555555556
#
#
# For Learning Rate: 0.001 and Threshold: 0.6 Accuracy: 89.24731182795699 %
#
# Confusion Matrix:
# [[67 15]
#  [ 5 99]]
#
# Accuracy: 0.8924731182795699
# Precision: 0.8170731707317073
# Recall: 0.9305555555555556
#
#
# For Learning Rate: 0.001 and Threshold: 0.7 Accuracy: 89.24731182795699 %
#
# Confusion Matrix:
# [[67 15]
#  [ 5 99]]
#
# Accuracy: 0.8924731182795699
# Precision: 0.8170731707317073
# Recall: 0.9305555555555556
#
#
# For Learning Rate: 0.0001 and Threshold: 0.3 Accuracy: 86.02150537634408 %
#
# Confusion Matrix:
# [[71 25]
#  [ 1 89]]
#
# Accuracy: 0.8602150537634409
# Precision: 0.7395833333333334
# Recall: 0.9861111111111112
#
#
# For Learning Rate: 0.0001 and Threshold: 0.4 Accuracy: 87.09677419354838 %
#
# Confusion Matrix:
# [[71 23]
#  [ 1 91]]
#
# Accuracy: 0.8709677419354839
# Precision: 0.7553191489361702
# Recall: 0.9861111111111112
#
#
# For Learning Rate: 0.0001 and Threshold: 0.5 Accuracy: 87.63440860215054 %
#
# Confusion Matrix:
# [[69 20]
#  [ 3 94]]
#
# Accuracy: 0.8763440860215054
# Precision: 0.7752808988764045
# Recall: 0.9583333333333334
#
#
# For Learning Rate: 0.0001 and Threshold: 0.6 Accuracy: 89.78494623655914 %
#
# Confusion Matrix:
# [[69 16]
#  [ 3 98]]
#
# Accuracy: 0.8978494623655914
# Precision: 0.8117647058823529
# Recall: 0.9583333333333334
#
#
# For Learning Rate: 0.0001 and Threshold: 0.7 Accuracy: 89.78494623655914 %
#
# Confusion Matrix:
# [[68 15]
#  [ 4 99]]
#
# Accuracy: 0.8978494623655914
# Precision: 0.8192771084337349
# Recall: 0.9444444444444444
#
#
# ==================================
# Mini Batch
# ==================================
# For Learning Rate: 0.01 and Threshold: 0.3 Accuracy: 92.47311827956989 %
#
# Confusion Matrix:
# [[ 65   7]
#  [  7 107]]
#
# Accuracy: 0.9247311827956989
# Precision: 0.9027777777777778
# Recall: 0.9027777777777778
#
#
# For Learning Rate: 0.01 and Threshold: 0.4 Accuracy: 92.47311827956989 %
#
# Confusion Matrix:
# [[ 65   7]
#  [  7 107]]
#
# Accuracy: 0.9247311827956989
# Precision: 0.9027777777777778
# Recall: 0.9027777777777778
#
#
# For Learning Rate: 0.01 and Threshold: 0.5 Accuracy: 92.47311827956989 %
#
# Confusion Matrix:
# [[ 65   7]
#  [  7 107]]
#
# Accuracy: 0.9247311827956989
# Precision: 0.9027777777777778
# Recall: 0.9027777777777778
#
#
# For Learning Rate: 0.01 and Threshold: 0.6 Accuracy: 92.47311827956989 %
#
# Confusion Matrix:
# [[ 65   7]
#  [  7 107]]
#
# Accuracy: 0.9247311827956989
# Precision: 0.9027777777777778
# Recall: 0.9027777777777778
#
#
# For Learning Rate: 0.01 and Threshold: 0.7 Accuracy: 92.47311827956989 %
#
# Confusion Matrix:
# [[ 65   7]
#  [  7 107]]
#
# Accuracy: 0.9247311827956989
# Precision: 0.9027777777777778
# Recall: 0.9027777777777778
#
#
# For Learning Rate: 0.001 and Threshold: 0.3 Accuracy: 93.01075268817203 %
#
# Confusion Matrix:
# [[ 66   7]
#  [  6 107]]
#
# Accuracy: 0.9301075268817204
# Precision: 0.9041095890410958
# Recall: 0.9166666666666666
#
#
# For Learning Rate: 0.001 and Threshold: 0.4 Accuracy: 93.01075268817203 %
#
# Confusion Matrix:
# [[ 66   7]
#  [  6 107]]
#
# Accuracy: 0.9301075268817204
# Precision: 0.9041095890410958
# Recall: 0.9166666666666666
#
#
# For Learning Rate: 0.001 and Threshold: 0.5 Accuracy: 93.01075268817203 %
#
# Confusion Matrix:
# [[ 66   7]
#  [  6 107]]
#
# Accuracy: 0.9301075268817204
# Precision: 0.9041095890410958
# Recall: 0.9166666666666666
#
#
# For Learning Rate: 0.001 and Threshold: 0.6 Accuracy: 93.01075268817203 %
#
# Confusion Matrix:
# [[ 66   7]
#  [  6 107]]
#
# Accuracy: 0.9301075268817204
# Precision: 0.9041095890410958
# Recall: 0.9166666666666666
#
#
# For Learning Rate: 0.001 and Threshold: 0.7 Accuracy: 92.47311827956989 %
#
# Confusion Matrix:
# [[ 65   7]
#  [  7 107]]
#
# Accuracy: 0.9247311827956989
# Precision: 0.9027777777777778
# Recall: 0.9027777777777778
#
#
# For Learning Rate: 0.0001 and Threshold: 0.3 Accuracy: 92.47311827956989 %
#
# Confusion Matrix:
# [[ 68  10]
#  [  4 104]]
#
# Accuracy: 0.9247311827956989
# Precision: 0.8717948717948718
# Recall: 0.9444444444444444
#
#
# For Learning Rate: 0.0001 and Threshold: 0.4 Accuracy: 93.01075268817203 %
#
# Confusion Matrix:
# [[ 68   9]
#  [  4 105]]
#
# Accuracy: 0.9301075268817204
# Precision: 0.8831168831168831
# Recall: 0.9444444444444444
#
#
# For Learning Rate: 0.0001 and Threshold: 0.5 Accuracy: 91.93548387096774 %
#
# Confusion Matrix:
# [[ 66   9]
#  [  6 105]]
#
# Accuracy: 0.9193548387096774
# Precision: 0.88
# Recall: 0.9166666666666666
#
#
# For Learning Rate: 0.0001 and Threshold: 0.6 Accuracy: 91.93548387096774 %
#
# Confusion Matrix:
# [[ 66   9]
#  [  6 105]]
#
# Accuracy: 0.9193548387096774
# Precision: 0.88
# Recall: 0.9166666666666666
#
#
# For Learning Rate: 0.0001 and Threshold: 0.7 Accuracy: 93.01075268817203 %
#
# Confusion Matrix:
# [[ 66   7]
#  [  6 107]]
#
# Accuracy: 0.9301075268817204
# Precision: 0.9041095890410958
# Recall: 0.9166666666666666
#
#
# ==================================
# Stochastic
# ==================================
# For Learning Rate: 0.01 and Threshold: 0.3 Accuracy: 73.11827956989248 %
#
# Confusion Matrix:
# [[72 50]
#  [ 0 64]]
#
# Accuracy: 0.7311827956989247
# Precision: 0.5901639344262295
# Recall: 1.0
#
#
# For Learning Rate: 0.01 and Threshold: 0.4 Accuracy: 93.01075268817203 %
#
# Confusion Matrix:
# [[ 68   9]
#  [  4 105]]
#
# Accuracy: 0.9301075268817204
# Precision: 0.8831168831168831
# Recall: 0.9444444444444444
#
#
# For Learning Rate: 0.01 and Threshold: 0.5 Accuracy: 94.6236559139785 %
#
# Confusion Matrix:
# [[ 63   1]
#  [  9 113]]
#
# Accuracy: 0.946236559139785
# Precision: 0.984375
# Recall: 0.875
#
#
# For Learning Rate: 0.01 and Threshold: 0.6 Accuracy: 91.39784946236558 %
#
# Confusion Matrix:
# [[ 69  13]
#  [  3 101]]
#
# Accuracy: 0.9139784946236559
# Precision: 0.8414634146341463
# Recall: 0.9583333333333334
#
#
# For Learning Rate: 0.01 and Threshold: 0.7 Accuracy: 88.70967741935483 %
#
# Confusion Matrix:
# [[71 20]
#  [ 1 94]]
#
# Accuracy: 0.8870967741935484
# Precision: 0.7802197802197802
# Recall: 0.9861111111111112
#
#
# For Learning Rate: 0.001 and Threshold: 0.3 Accuracy: 88.17204301075269 %
#
# Confusion Matrix:
# [[ 50   0]
#  [ 22 114]]
#
# Accuracy: 0.8817204301075269
# Precision: 1.0
# Recall: 0.6944444444444444
#
#
# For Learning Rate: 0.001 and Threshold: 0.4 Accuracy: 95.16129032258065 %
#
# Confusion Matrix:
# [[ 65   2]
#  [  7 112]]
#
# Accuracy: 0.9516129032258065
# Precision: 0.9701492537313433
# Recall: 0.9027777777777778
#
#
# For Learning Rate: 0.001 and Threshold: 0.5 Accuracy: 95.16129032258065 %
#
# Confusion Matrix:
# [[ 65   2]
#  [  7 112]]
#
# Accuracy: 0.9516129032258065
# Precision: 0.9701492537313433
# Recall: 0.9027777777777778
#
#
# For Learning Rate: 0.001 and Threshold: 0.6 Accuracy: 94.6236559139785 %
#
# Confusion Matrix:
# [[ 63   1]
#  [  9 113]]
#
# Accuracy: 0.946236559139785
# Precision: 0.984375
# Recall: 0.875
#
#
# For Learning Rate: 0.001 and Threshold: 0.7 Accuracy: 93.01075268817203 %
#
# Confusion Matrix:
# [[ 66   7]
#  [  6 107]]
#
# Accuracy: 0.9301075268817204
# Precision: 0.9041095890410958
# Recall: 0.9166666666666666
#
#
# For Learning Rate: 0.0001 and Threshold: 0.3 Accuracy: 94.6236559139785 %
#
# Confusion Matrix:
# [[ 63   1]
#  [  9 113]]
#
# Accuracy: 0.946236559139785
# Precision: 0.984375
# Recall: 0.875
#
#
# For Learning Rate: 0.0001 and Threshold: 0.4 Accuracy: 90.32258064516128 %
#
# Confusion Matrix:
# [[69 15]
#  [ 3 99]]
#
# Accuracy: 0.9032258064516129
# Precision: 0.8214285714285714
# Recall: 0.9583333333333334
#
#
# For Learning Rate: 0.0001 and Threshold: 0.5 Accuracy: 92.47311827956989 %
#
# Confusion Matrix:
# [[ 69  11]
#  [  3 103]]
#
# Accuracy: 0.9247311827956989
# Precision: 0.8625
# Recall: 0.9583333333333334
#
#
# For Learning Rate: 0.0001 and Threshold: 0.6 Accuracy: 95.16129032258065 %
#
# Confusion Matrix:
# [[ 65   2]
#  [  7 112]]
#
# Accuracy: 0.9516129032258065
# Precision: 0.9701492537313433
# Recall: 0.9027777777777778
#
#
# For Learning Rate: 0.0001 and Threshold: 0.7 Accuracy: 95.16129032258065 %
#
# Confusion Matrix:
# [[ 65   2]
#  [  7 112]]
#
# Accuracy: 0.9516129032258065
# Precision: 0.9701492537313433
# Recall: 0.9027777777777778

# %% [markdown]
# LR2

# %%
df2=df
for i in df.columns:
  if df2[i].isnull().sum()==0:
    continue
  else:
    n=df.shape[0]-df2[i].isnull().sum()
    meanval=df[i].sum()/n
    df2[i].fillna(value=meanval, inplace=True)
print(df2.shape)

for i in df.columns:
  if i=='id' or i=='diagnosis':
    continue
  else:
    df2[i] = (df2[i] - df2[i].mean())/df2[i].std()

df_train = df2.sample(frac=0.67, random_state=1)
df_test=df2.drop(df_train.index)
print (df_train.shape, df_test.shape)

X_train = df_train[X_cols]
X_test = df_test[X_cols]
y_train = (((df_train[Y_col]).apply(ord))/11-6).astype('int')
y_test = (((df_test[Y_col]).apply(ord))/11-6).astype('int')


X_train=np.array(X_train)
y_train=np.array(y_train)
X_test=np.array(X_test)
y_test=np.array(y_test)

print(X_train.shape, y_train.shape)
# Out:
# (569, 32)
# (381, 32) (188, 32)
# (381, 30) (381,)

# %%
l=[0.01,0.001,0.0001]
t=[0.3,0.4,0.5,0.6,0.7]
def accuracy (y_pred, y_test):
  return np.sum (y_pred==y_test)/len(y_test)

print("==================================")
print("Batch")
print("==================================")
for k in l:
  for j in t:
    LR2= LogisticRegression(lr=k,p_thresh=j) #give diff learning rates and prob thresholds
    c,e=LR2.batchfit(X_train, y_train) 
    y_pred=LR2.predict(X_test)
    acc= accuracy(y_pred, y_test)
    print ("For Learning Rate:",k,"and Threshold:",j,"Accuracy:",acc*100,"%")
    print(" ")
    TP=0
    FP=0
    TN=0
    FN=0

    for i in range(len(y_pred)):
      if y_pred[i]==1 and y_test[i]==1:
        TP+=1
      elif y_pred[i]==1 and y_test[i]==0:
        FP+=1
      elif y_pred[i]==0 and y_test[i]==1:
        FN+=1
      elif y_pred[i]==0 and y_test[i]==0:
        TN+=1
    print("Confusion Matrix:")
    print(np.array([[TP,FP],[FN,TN]]))
    print(" ")
    print("Accuracy:", (TP + TN)/(TP + TN + FP + FN))
    print("Precision:", TP/(TP + FP))
    print("Recall:", TP/(TP + FN))
    print(" ")
    costs=np.squeeze(c)
    plt.plot(c)
    plt.xlabel("Cost")
    plt.ylabel("Number of Iterations")
    plt.show()
    print(" ")
    print(" ")


print("==================================")
print("Mini Batch")
print("==================================")
for k in l:
  for j in t:
    LR2= LogisticRegression(lr=k,p_thresh=j) #give diff learning rates and prob thresholds
    c,e=LR2.minifit(X_train, y_train) 
    y_pred=LR2.predict(X_test)
    acc= accuracy(y_pred, y_test)
    print ("For Learning Rate:",k,"and Threshold:",j,"Accuracy:",acc*100,"%")
    print(" ")
    TP=0
    FP=0
    TN=0
    FN=0

    for i in range(len(y_pred)):
      if y_pred[i]==1 and y_test[i]==1:
        TP+=1
      elif y_pred[i]==1 and y_test[i]==0:
        FP+=1
      elif y_pred[i]==0 and y_test[i]==1:
        FN+=1
      elif y_pred[i]==0 and y_test[i]==0:
        TN+=1
    print("Confusion Matrix:")
    print(np.array([[TP,FP],[FN,TN]]))
    print(" ")
    print("Accuracy:", (TP + TN)/(TP + TN + FP + FN))
    print("Precision:", TP/(TP + FP))
    print("Recall:", TP/(TP + FN))
    print(" ")
    costs=np.squeeze(c)
    plt.plot(c)
    plt.xlabel("Cost")
    plt.ylabel("Number of Iterations")
    plt.show()
    print(" ")
    print(" ")


print("==================================")
print("Stochastic")
print("==================================")
for k in l:
  for j in t:
    LR2= LogisticRegression(lr=k,p_thresh=j) #give diff learning rates and prob thresholds
    c,e=LR2.sgdfit(X_train, y_train) 
    y_pred=LR2.predict(X_test)
    acc= accuracy(y_pred, y_test)
    print ("For Learning Rate:",k,"and Threshold:",j,"Accuracy:",acc*100,"%")
    print(" ")
    TP=0
    FP=0
    TN=0
    FN=0

    for i in range(len(y_pred)):
      if y_pred[i]==1 and y_test[i]==1:
        TP+=1
      elif y_pred[i]==1 and y_test[i]==0:
        FP+=1
      elif y_pred[i]==0 and y_test[i]==1:
        FN+=1
      elif y_pred[i]==0 and y_test[i]==0:
        TN+=1
    print("Confusion Matrix:")
    print(np.array([[TP,FP],[FN,TN]]))
    print(" ")
    print("Accuracy:", (TP + TN)/(TP + TN + FP + FN))
    print("Precision:", TP/(TP + FP))
    print("Recall:", TP/(TP + FN))
    print(" ")
    costs=np.squeeze(c)
    plt.plot(c)
    plt.xlabel("Cost")
    plt.ylabel("Number of Iterations")
    plt.show()
    print(" ")
    print(" ")
# Out:
# ==================================
# Batch
# ==================================
# For Learning Rate: 0.01 and Threshold: 0.3 Accuracy: 97.3404255319149 %
#
# Confusion Matrix:
# [[ 69   3]
#  [  2 114]]
#
# Accuracy: 0.973404255319149
# Precision: 0.9583333333333334
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.01 and Threshold: 0.4 Accuracy: 98.93617021276596 %
#
# Confusion Matrix:
# [[ 69   0]
#  [  2 117]]
#
# Accuracy: 0.9893617021276596
# Precision: 1.0
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.01 and Threshold: 0.5 Accuracy: 98.40425531914893 %
#
# Confusion Matrix:
# [[ 68   0]
#  [  3 117]]
#
# Accuracy: 0.9840425531914894
# Precision: 1.0
# Recall: 0.9577464788732394
#
#
# For Learning Rate: 0.01 and Threshold: 0.6 Accuracy: 96.80851063829788 %
#
# Confusion Matrix:
# [[ 65   0]
#  [  6 117]]
#
# Accuracy: 0.9680851063829787
# Precision: 1.0
# Recall: 0.9154929577464789
#
#
# For Learning Rate: 0.01 and Threshold: 0.7 Accuracy: 94.68085106382979 %
#
# Confusion Matrix:
# [[ 61   0]
#  [ 10 117]]
#
# Accuracy: 0.9468085106382979
# Precision: 1.0
# Recall: 0.8591549295774648
#
#
# For Learning Rate: 0.001 and Threshold: 0.3 Accuracy: 90.95744680851064 %
#
# Confusion Matrix:
# [[ 70  16]
#  [  1 101]]
#
# Accuracy: 0.9095744680851063
# Precision: 0.813953488372093
# Recall: 0.9859154929577465
#
#
# For Learning Rate: 0.001 and Threshold: 0.4 Accuracy: 95.2127659574468 %
#
# Confusion Matrix:
# [[ 69   7]
#  [  2 110]]
#
# Accuracy: 0.9521276595744681
# Precision: 0.9078947368421053
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.001 and Threshold: 0.5 Accuracy: 95.2127659574468 %
#
# Confusion Matrix:
# [[ 63   1]
#  [  8 116]]
#
# Accuracy: 0.9521276595744681
# Precision: 0.984375
# Recall: 0.8873239436619719
#
#
# For Learning Rate: 0.001 and Threshold: 0.6 Accuracy: 94.14893617021278 %
#
# Confusion Matrix:
# [[ 61   1]
#  [ 10 116]]
#
# Accuracy: 0.9414893617021277
# Precision: 0.9838709677419355
# Recall: 0.8591549295774648
#
#
# For Learning Rate: 0.001 and Threshold: 0.7 Accuracy: 91.48936170212765 %
#
# Confusion Matrix:
# [[ 56   1]
#  [ 15 116]]
#
# Accuracy: 0.9148936170212766
# Precision: 0.9824561403508771
# Recall: 0.7887323943661971
#
#
# For Learning Rate: 0.0001 and Threshold: 0.3 Accuracy: 37.765957446808514 %
#
# Confusion Matrix:
# [[ 71 117]
#  [  0   0]]
#
# Accuracy: 0.3776595744680851
# Precision: 0.3776595744680851
# Recall: 1.0
#
#
# For Learning Rate: 0.0001 and Threshold: 0.4 Accuracy: 54.25531914893617 %
#
# Confusion Matrix:
# [[71 86]
#  [ 0 31]]
#
# Accuracy: 0.5425531914893617
# Precision: 0.45222929936305734
# Recall: 1.0
#
#
# For Learning Rate: 0.0001 and Threshold: 0.5 Accuracy: 94.14893617021278 %
#
# Confusion Matrix:
# [[ 63   3]
#  [  8 114]]
#
# Accuracy: 0.9414893617021277
# Precision: 0.9545454545454546
# Recall: 0.8873239436619719
#
#
# For Learning Rate: 0.0001 and Threshold: 0.6 Accuracy: 81.38297872340425 %
#
# Confusion Matrix:
# [[ 37   1]
#  [ 34 116]]
#
# Accuracy: 0.8138297872340425
# Precision: 0.9736842105263158
# Recall: 0.5211267605633803
#
#
# For Learning Rate: 0.0001 and Threshold: 0.7 Accuracy: 66.48936170212765 %
#
# Confusion Matrix:
# [[  8   0]
#  [ 63 117]]
#
# Accuracy: 0.6648936170212766
# Precision: 1.0
# Recall: 0.11267605633802817
#
#
# ==================================
# Mini Batch
# ==================================
# For Learning Rate: 0.01 and Threshold: 0.3 Accuracy: 98.40425531914893 %
#
# Confusion Matrix:
# [[ 69   1]
#  [  2 116]]
#
# Accuracy: 0.9840425531914894
# Precision: 0.9857142857142858
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.01 and Threshold: 0.4 Accuracy: 98.93617021276596 %
#
# Confusion Matrix:
# [[ 69   0]
#  [  2 117]]
#
# Accuracy: 0.9893617021276596
# Precision: 1.0
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.01 and Threshold: 0.5 Accuracy: 98.40425531914893 %
#
# Confusion Matrix:
# [[ 68   0]
#  [  3 117]]
#
# Accuracy: 0.9840425531914894
# Precision: 1.0
# Recall: 0.9577464788732394
#
#
# For Learning Rate: 0.01 and Threshold: 0.6 Accuracy: 97.3404255319149 %
#
# Confusion Matrix:
# [[ 66   0]
#  [  5 117]]
#
# Accuracy: 0.973404255319149
# Precision: 1.0
# Recall: 0.9295774647887324
#
#
# For Learning Rate: 0.01 and Threshold: 0.7 Accuracy: 96.27659574468085 %
#
# Confusion Matrix:
# [[ 64   0]
#  [  7 117]]
#
# Accuracy: 0.9627659574468085
# Precision: 1.0
# Recall: 0.9014084507042254
#
#
# For Learning Rate: 0.001 and Threshold: 0.3 Accuracy: 97.87234042553192 %
#
# Confusion Matrix:
# [[ 69   2]
#  [  2 115]]
#
# Accuracy: 0.9787234042553191
# Precision: 0.971830985915493
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.001 and Threshold: 0.4 Accuracy: 98.93617021276596 %
#
# Confusion Matrix:
# [[ 69   0]
#  [  2 117]]
#
# Accuracy: 0.9893617021276596
# Precision: 1.0
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.001 and Threshold: 0.5 Accuracy: 98.40425531914893 %
#
# Confusion Matrix:
# [[ 68   0]
#  [  3 117]]
#
# Accuracy: 0.9840425531914894
# Precision: 1.0
# Recall: 0.9577464788732394
#
#
# For Learning Rate: 0.001 and Threshold: 0.6 Accuracy: 96.80851063829788 %
#
# Confusion Matrix:
# [[ 65   0]
#  [  6 117]]
#
# Accuracy: 0.9680851063829787
# Precision: 1.0
# Recall: 0.9154929577464789
#
#
# For Learning Rate: 0.001 and Threshold: 0.7 Accuracy: 95.74468085106383 %
#
# Confusion Matrix:
# [[ 63   0]
#  [  8 117]]
#
# Accuracy: 0.9574468085106383
# Precision: 1.0
# Recall: 0.8873239436619719
#
#
# For Learning Rate: 0.0001 and Threshold: 0.3 Accuracy: 94.68085106382979 %
#
# Confusion Matrix:
# [[ 70   9]
#  [  1 108]]
#
# Accuracy: 0.9468085106382979
# Precision: 0.8860759493670886
# Recall: 0.9859154929577465
#
#
# For Learning Rate: 0.0001 and Threshold: 0.4 Accuracy: 96.80851063829788 %
#
# Confusion Matrix:
# [[ 69   4]
#  [  2 113]]
#
# Accuracy: 0.9680851063829787
# Precision: 0.9452054794520548
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.0001 and Threshold: 0.5 Accuracy: 96.80851063829788 %
#
# Confusion Matrix:
# [[ 66   1]
#  [  5 116]]
#
# Accuracy: 0.9680851063829787
# Precision: 0.9850746268656716
# Recall: 0.9295774647887324
#
#
# For Learning Rate: 0.0001 and Threshold: 0.6 Accuracy: 94.68085106382979 %
#
# Confusion Matrix:
# [[ 62   1]
#  [  9 116]]
#
# Accuracy: 0.9468085106382979
# Precision: 0.9841269841269841
# Recall: 0.8732394366197183
#
#
# For Learning Rate: 0.0001 and Threshold: 0.7 Accuracy: 93.61702127659575 %
#
# Confusion Matrix:
# [[ 59   0]
#  [ 12 117]]
#
# Accuracy: 0.9361702127659575
# Precision: 1.0
# Recall: 0.8309859154929577
#
#
# ==================================
# Stochastic
# ==================================
# For Learning Rate: 0.01 and Threshold: 0.3 Accuracy: 97.87234042553192 %
#
# Confusion Matrix:
# [[ 68   1]
#  [  3 116]]
#
# Accuracy: 0.9787234042553191
# Precision: 0.9855072463768116
# Recall: 0.9577464788732394
#
#
# For Learning Rate: 0.01 and Threshold: 0.4 Accuracy: 98.40425531914893 %
#
# Confusion Matrix:
# [[ 69   1]
#  [  2 116]]
#
# Accuracy: 0.9840425531914894
# Precision: 0.9857142857142858
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.01 and Threshold: 0.5 Accuracy: 96.80851063829788 %
#
# Confusion Matrix:
# [[ 66   1]
#  [  5 116]]
#
# Accuracy: 0.9680851063829787
# Precision: 0.9850746268656716
# Recall: 0.9295774647887324
#
#
# For Learning Rate: 0.01 and Threshold: 0.6 Accuracy: 96.80851063829788 %
#
# Confusion Matrix:
# [[ 66   1]
#  [  5 116]]
#
# Accuracy: 0.9680851063829787
# Precision: 0.9850746268656716
# Recall: 0.9295774647887324
#
#
# For Learning Rate: 0.01 and Threshold: 0.7 Accuracy: 96.27659574468085 %
#
# Confusion Matrix:
# [[ 65   1]
#  [  6 116]]
#
# Accuracy: 0.9627659574468085
# Precision: 0.9848484848484849
# Recall: 0.9154929577464789
#
#
# For Learning Rate: 0.001 and Threshold: 0.3 Accuracy: 97.87234042553192 %
#
# Confusion Matrix:
# [[ 68   1]
#  [  3 116]]
#
# Accuracy: 0.9787234042553191
# Precision: 0.9855072463768116
# Recall: 0.9577464788732394
#
#
# For Learning Rate: 0.001 and Threshold: 0.4 Accuracy: 98.40425531914893 %
#
# Confusion Matrix:
# [[ 68   0]
#  [  3 117]]
#
# Accuracy: 0.9840425531914894
# Precision: 1.0
# Recall: 0.9577464788732394
#
#
# For Learning Rate: 0.001 and Threshold: 0.5 Accuracy: 97.87234042553192 %
#
# Confusion Matrix:
# [[ 67   0]
#  [  4 117]]
#
# Accuracy: 0.9787234042553191
# Precision: 1.0
# Recall: 0.9436619718309859
#
#
# For Learning Rate: 0.001 and Threshold: 0.6 Accuracy: 97.87234042553192 %
#
# Confusion Matrix:
# [[ 67   0]
#  [  4 117]]
#
# Accuracy: 0.9787234042553191
# Precision: 1.0
# Recall: 0.9436619718309859
#
#
# For Learning Rate: 0.001 and Threshold: 0.7 Accuracy: 96.80851063829788 %
#
# Confusion Matrix:
# [[ 65   0]
#  [  6 117]]
#
# Accuracy: 0.9680851063829787
# Precision: 1.0
# Recall: 0.9154929577464789
#
#
# For Learning Rate: 0.0001 and Threshold: 0.3 Accuracy: 97.87234042553192 %
#
# Confusion Matrix:
# [[ 69   2]
#  [  2 115]]
#
# Accuracy: 0.9787234042553191
# Precision: 0.971830985915493
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.0001 and Threshold: 0.4 Accuracy: 98.93617021276596 %
#
# Confusion Matrix:
# [[ 69   0]
#  [  2 117]]
#
# Accuracy: 0.9893617021276596
# Precision: 1.0
# Recall: 0.971830985915493
#
#
# For Learning Rate: 0.0001 and Threshold: 0.5 Accuracy: 98.40425531914893 %
#
# Confusion Matrix:
# [[ 68   0]
#  [  3 117]]
#
# Accuracy: 0.9840425531914894
# Precision: 1.0
# Recall: 0.9577464788732394
#
#
# For Learning Rate: 0.0001 and Threshold: 0.6 Accuracy: 96.80851063829788 %
#
# Confusion Matrix:
# [[ 65   0]
#  [  6 117]]
#
# Accuracy: 0.9680851063829787
# Precision: 1.0
# Recall: 0.9154929577464789
#
#
# For Learning Rate: 0.0001 and Threshold: 0.7 Accuracy: 96.80851063829788 %
#
# Confusion Matrix:
# [[ 65   0]
#  [  6 117]]
#
# Accuracy: 0.9680851063829787
# Precision: 1.0
# Recall: 0.9154929577464789
